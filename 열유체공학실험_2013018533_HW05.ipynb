# %% [markdown]
# <a href="https://colab.research.google.com/github/sjw940/-1_HW_-_2013018533/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98_2013018533_HW05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits import mplot3d
def homework05():
    theta = 2 * np.pi * np.random.random(1000)
    r = 6 * np.random.random(1000)
    x = np.ravel(r * np.sin(theta))
    y = np.ravel(r * np.cos(theta))
    z = np.exp(-0.1*x**2-0.1*y**2)
    return x, y, z

x, y, z = homework05()

ax = plt.axes(projection='3d')
# TODO
# 아래 ax.plot_trisurf 함수 내부 인자를 완성하시오.
ax.plot_trisurf(x,y,z, cmap='viridis',edgecolor='none');
ax.set_xlim(-5, 5); ax.set_ylim(-5, 5); ax.set_zlim(0, 1);
